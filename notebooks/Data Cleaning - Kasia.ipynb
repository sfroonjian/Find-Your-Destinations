# %% [markdown]
# # Data Preparation for Find your Destination Travel App

# %%
# Import dependencies to be used for the data cleaning or exploring 
import numpy as np
import pandas as pd
import os 
from bs4 import BeautifulSoup
import requests
from splinter import Browser

# %% [markdown]
# Data set for the locatinos of all US campsites

# %%
# Load and read the CSV 
camp_file = "us_campsites.csv"
camp_df = pd.read_csv(camp_file)

# %%
# Data exploration of campsites 
camp_df
# Out:
#        longitude  latitude  code                               name  type  \
# 0        -92.875    42.953  ACKL           Ackley Creek County Park    CP
# 1        -93.724    41.738  ACOR    Acorn Valley - Saylorville Lake   COE
# 2        -94.643    41.498  ADAI                    Adair City Park    CP
# 3        -92.210    43.120  ADOL                 Adolph Munson Park    CP
# 4        -92.348    43.090  AIRP                  Airport Lake Park    CP
# ...          ...       ...   ...                                ...   ...
# 11403    -95.151    30.665  WOLP  Wolf Creek Park - Lake Livingston  AUTH
# 11404   -100.646    36.227  WOLC         Wolf Creek Park - Perryton    CP
# 11405    -96.535    30.295  YEGU      Yegua Creek - Lake Somerville   COE
# 11406    -97.129    29.305  YOAK                   Yoakum City Park    CP
# 11407   -102.818    33.049  YOAK                 Yoakum County Park    CP
#
#               phone          dates_open                       comments  \
# 0      641.756.3490                 NaN                            NaN
# 1      515.276.0429  early jun-late aug                            NaN
# 2      641.742.3751                 NaN                            NaN
# 3               NaN                 NaN                            NaN
# 4               NaN                 NaN               primitive - tent
# ...             ...                 ...                            ...
# 11403  936.653.4312                 NaN                            NaN
# 11404  806.435.4559                 NaN                            NaN
# 11405  979.596.1622            all year                            NaN
# 11406           NaN                 NaN  concrete - not good for tents
# 11407  806.592.3166                 NaN                            NaN
#
#       num_sites  elevation           amenities state  nearest_town_distance  \
# 0            40        NaN       E DP DW SH L$    IA                    1.0
# 1            70        NaN    E DP DW SH RS PA    IA                   11.2
# 2            12        NaN                E SH    IA                    0.2
# 3           NaN        NaN               NH PT    IA                    6.8
# 4            50        NaN                E PT    IA                    2.6
# ...         ...        ...                 ...   ...                    ...
# 11403       100        NaN            WE DP SH    TX                    NaN
# 11404        94     2665.0         WE DP DW SH    TX                   14.8
# 11405        80        NaN         WE DP SH RS    TX                    3.5
# 11406        25        NaN  WES DP FT DW SH L$    TX                    1.8
# 11407        16     3602.0               WE DP    TX                    5.9
#
#       nearest_town_bearing         city
# 0                       SW  Marble Rock
# 1                       NW   Des Moines
# 2                        S        Adair
# 3                       NE  New Hampton
# 4                       NW  New Hampton
# ...                    ...          ...
# 11403                  NaN          NaN
# 11404                   SE     Perryton
# 11405                    S   Somerville
# 11406                   NE       Yoakum
# 11407                    N  Denver City
#
# [11408 rows x 15 columns]

# %%
# Get rankings of the states with the most campsites: group by location columns 
camps = camp_df.groupby(["state"]).count()
camps_sort = camps.sort_values("longitude", ascending = False)
camps_sort

# %%
# We're mainly interested in the latitude and longitude for the states so we will make the dataset smaller 
camp_df = camp_df[["latitude","longitude","name","state"]]
camp_df
# Out:
#        latitude  longitude                               name state
# 0        42.953    -92.875           Ackley Creek County Park    IA
# 1        41.738    -93.724    Acorn Valley - Saylorville Lake    IA
# 2        41.498    -94.643                    Adair City Park    IA
# 3        43.120    -92.210                 Adolph Munson Park    IA
# 4        43.090    -92.348                  Airport Lake Park    IA
# ...         ...        ...                                ...   ...
# 11403    30.665    -95.151  Wolf Creek Park - Lake Livingston    TX
# 11404    36.227   -100.646         Wolf Creek Park - Perryton    TX
# 11405    30.295    -96.535      Yegua Creek - Lake Somerville    TX
# 11406    29.305    -97.129                   Yoakum City Park    TX
# 11407    33.049   -102.818                 Yoakum County Park    TX
#
# [11408 rows x 4 columns]

# %%
# Export to CSV - ready to go 
camp_df.to_csv("campsite_selected.csv", index=False, header=True)

# %% [markdown]
# Data for the value of the dolar per state
# Note: I started this analysis but it gives a lot of extra data so instead I used a scraping software to make it easier

# %%
url = "https://www.usatoday.com/story/money/economy/2018/05/10/cost-of-living-value-of-dollar-in-every-state/34567549/"

# %%
# Retrieve page with the requests module
response = requests.get(url)

# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="gnt__njs" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1,minimum-scale=1" name="viewport"/>
#   <meta content="#0098FE" name="theme-color"/>
#   <title>
#    Cost of living: The value of a dollar in every state
#   </title>
#   <meta content="Cost of living: The purchasing power of a dollar in every state" property="og:title"/>
#   <link href="https://amp.usatoday.com/amp/34567549" rel="amphtml"/>
#   <meta content="Michael B. Sauter" property="article:author"/>
#   <meta content="free" property="article:content_tier"/>
#   <meta content="false" property="article:opinion"/>
#   <link href="//user.usatoday.com" rel="dns-prefetch"/>
#   <link href="https://user.usatoday.com" rel="preconnect"/>
#   <link href="//content-static.gannett.com" rel="dns-prefetch"/>
#   <link href="//www.gannett-cdn.com" rel="dns-prefetch"/>
#   <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/>
#   <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
#   <link href="//adservice.google.com" rel="dns-prefetch"/>
#   <link href="https://adservice.google.com" rel="preconnect"/>
#   <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
#   <link href="https://tpc.googlesyndication.com" rel="preconnect"/>
#   <link href="//googleads.g.doubleclick.net" rel="dns-prefetch"/>
#   <link href="//s0.2mdn.net" rel="dns-prefetch"/>
#   <link href="//partner.googleadservices.com" rel="dns-prefetch"/>
#   <link href="//www.googletagservices.com" rel="dns-prefetch"/>
#   <link href="https://www.googletagservices.com" rel="preconnect"/>
#   <link href="//static.adsafeprotected.com" rel="dns-prefetch"/>
#   <link href="https://static.adsafeprotected.com" rel="preconnect"/>
#   <link href="//pixel.adsafeprotected.com" rel="dns-prefetch"/>
#   <link crossorigin="" href="https://pixel.adsafeprotected.com" rel="preconnect"/>
#   <link href="//c.amazon-adsystem.com" rel="dns-prefetch"/>
#   <link href="//c.amazon-adsystem.com" rel="preconnect"/>
#   <link href="//js-sec.indexww.com" rel="dns-prefetch"/>
#   <link href="https://js-sec.indexww.com" rel="preconnect"/>
#   <link href="//aax.amazon-adsystem.com" rel="dns-prefetch"/>
#   <link href="//aax.amazon-adsystem.com" rel="preconnect"/>
#   <link href="//fastlane.rubiconproject.com" rel="dns-prefetch"/>
#   <link href="https://fastlane.rubiconproject.com" rel="preconnect"/>
#   <link href="//bidder.criteo.com" rel="dns-prefetch"/>
#   <link href="https://bidder.criteo.com" rel="preconnect"/>
#   <link href="//static.criteo.com" rel="dns-prefetch"/>
#   <link href="//colossusssp.com" rel="dns-prefetch"/>
#   <link href="https://colossusssp.com" rel="preconnect"/>
#   <link href="//gannett-d.openx.net" rel="dns-prefetch"/>
#   <link href="https://gannett-d.openx.net" rel="preconnect"/>
#   <link href="//hbopenbid.pubmatic.com" rel="dns-prefetch"/>
#   <link href="https://hbopenbid.pubmatic.com" rel="preconnect"/>
#   <link href="//ads.pubmatic.com" rel="dns-prefetch"/>
#   <link href="//as-sec.casalemedia.com" rel="dns-prefetch"/>
#   <link href="https://as-sec.casalemedia.com" rel="preconnect"/>
#   <link href="//ib.adnxs.com" rel="dns-prefetch"/>
#   <link href="https://ib.adnxs.com" rel="preconnect"/>
#   <link href="//adserver.adtechus.com" rel="dns-prefetch"/>
#   <link href="https://adserver.adtechus.com" rel="preconnect"/>
#   <link href="//apex.go.sonobi.com" rel="dns-prefetch"/>
#   <link href="https://apex.go.sonobi.com" rel="preconnect"/>
#   <link href="//sofia.trustx.org" rel="dns-prefetch"/>
#   <link href="https://sofia.trustx.org" rel="preconnect"/>
#   <link href="//tlx.3lift.com" rel="dns-prefetch"/>
#   <link href="https://tlx.3lift.com" rel="preconnect"/>
#   <link href="//e.serverbid.com" rel="dns-prefetch"/>
#   <link href="https://e.serverbid.com" rel="preconnect"/>
#   <link href="//confiant-integrations.global.ssl.fastly.net" rel="dns-prefetch"/>
#   <link href="https://confiant-integrations.global.ssl.fastly.net" rel="preconnect"/>
#   <link href="https://s0.2mdn.net" rel="preconnect"/>
#   <link href="https://ads.adaptv.advertising.com" rel="preconnect"/>
#   <link href="https://search.spotxchange.com" rel="preconnect"/>
#   <link href="https://static.adsafeprotected.com" rel="preconnect"/>
#   <link href="https://imasdk.googleapis.com" rel="preconnect"/>
#   <link href="//ads.adaptv.advertising.com" rel="dns-prefetch"/>
#   <link href="//search.spotxchange.com" rel="dns-prefetch"/>
#   <link href="//static.adsafeprotected.com" rel="dns-prefetch"/>
#   <link href="//imasdk.googleapis.com" rel="dns-prefetch"/>
#   <link href="//a.teads.com" rel="dns-prefetch"/>
#   <link href="//geolocation.onetrust.com" rel="dns-prefetch"/>
#   <link href="https://geolocation.onetrust.com" rel="preconnect"/>
#   <link href="//atoms.usatoday.com" rel="dns-prefetch"/>
#   <link href="//cdn.taboola.com" rel="dns-prefetch"/>
#   <link href="https://cdn.taboola.com" rel="preconnect"/>
#   <link href="//trc.taboola.com" rel="dns-prefetch"/>
#   <link href="https://trc.taboola.com" rel="preconnect"/>
#   <link as="fetch" crossorigin="use-credentials" href="https://user.usatoday.com/USAT-GUP/user/" rel="preload" type="application/json"/>
#   <link as="script" href="/tangstatic/js/pbjsandwich-q1a2z300ab4198.min.js" rel="preload"/>
#   <link as="script" href="https://c.amazon-adsystem.com/aax2/apstag.js" rel="preload"/>
#   <link as="script" href="https://js-sec.indexww.com/ht/p/184808-89514051626416.js" rel="preload"/>
#   <link as="script" href="https://static.adsafeprotected.com/iasPET.1.js" rel="preload"/>
#   <link as="script" crossorigin="" href="https://static.criteo.net/js/ld/publishertag.prebid.js" rel="preload"/>
#   <link as="script" href="https://securepubads.g.doubleclick.net/tag/js/gpt.js" rel="preload"/>
#   <link as="script" href="https://confiant-integrations.global.ssl.fastly.net/r5TdgVvkbv-PeaJCKaQfCh5Xsto/gpt_and_prebid_v3l/config.js" rel="preload"/>
#   <link as="script" href="/tangstatic/js/main-q1a2z39e4056db.min.js" rel="preload"/>
#   <link as="script" href="https://geolocation.onetrust.com/cookieconsentpub/v1/geo/location/gnt.otgc" rel="preload"/>
#   <link as="script" href="https://cdn.taboola.com/libtrc/usatodaydemo/loader.js" rel="preload"/>
#   <link as="script" href="https://www.gannett-cdn.com/gannett-web/apps/teal/dist/controls-4edfda22.min.js" rel="preload"/>
#   <link as="script" href="https://www.gannett-cdn.com/gannett-web/apps/teal/dist/share-454f9438.min.js" rel="preload"/>
#   <link as="script" href="https://www.gannett-cdn.com/gannett-web/apps/teal/dist/tealplayer-3928e7f8.min.js" rel="preload"/>
#   <link as="script" href="https://www.gannett-cdn.com/gannett-web/apps/teal/dist/teal-comscore-f1701de9.min.js" rel="preload"/>
#   <link as="script" href="https://www.gannett-cdn.com/gannett-web/apps/teal/dist/teal-heartbeat-6c3c72e8.min.js" rel="preload"/>
#   <link as="script" href="https://www.gannett-cdn.com/gannett-web/apps/teal/dist/teal-hls-0887d8c7.min.js" rel="preload"/>
#   <link as="script" href="https://www.gannett-cdn.com/gannett-web/apps/teal/dist/encore-c29e248c.min.js" rel="preload"/>
#   <link as="script" href="https://www.gannett-cdn.com/gannett-web/apps/teal/dist/teal-ima-a6d09a96.min.js" rel="preload"/>
#   <link as="script" href="https://www.gannett-cdn.com/gannett-web/apps/teal/dist/vendor/hls/hls.light.0.12.4.min.js" rel="preload"/>
#   <link as="script" href="https://www.gannett-cdn.com/gannett-web/apps/teal/dist/vendor/comscore/streamsense-5.1.1.160316.min.js" rel="preload"/>
#   <link as="script" href="https://www.gannett-cdn.com/gannett-web/apps/teal/dist/vendor/adobe/MediaSDK.2.2.0.min.js" rel="preload"/>
#   <link as="script" href="https://www.gannett-cdn.com/gannett-web/apps/teal/dist/vendor/adobe/VisitorAPI-3.4.0.min.js" rel="preload"/>
#   <link as="script" href="https://www.gannett-cdn.com/gannett-web/apps/teal/dist/vendor/adobe/AppMeasurement-2.11.0.min.js" rel="preload"/>
#   <link as="script" href="https://www.gannett-cdn.com/gannett-web/apps/teal/dist/vendor/ias/ias-3.5.1.min.js" rel="preload"/>
#   <link as="script" href="https://s0.2mdn.net/instream/video/client.js" rel="preload"/>
#   <link as="script" href="https://imasdk.googleapis.com/js/sdkloader/ima3.js" rel="preload"/>
#   <meta content="While a dollar bill looks and feels the same all over the United States, its value is often very different depending on where it is spent." name="description"/>
#   <meta content="While a dollar bill looks and feels the same all over the United States, its value is often very different depending on where it is spent." property="og:description"/>
#   <meta content="13652355666,48958576760,156345381090801,110471702456365,6566864515,137698179626815,315942225236045,927427260614748,183850168300771,1443524575938047,251228454889939,158095147555989,115535341805950,236655713446291,1621466394844549,250325640686,177037772444433,1972936962947967,2047091012096533,535551216797440" property="fb:pages"/>
#   <meta content="215046668549694" property="fb:app_id"/>
#   <link href="https://247wallst.com/special-report/2018/05/04/value-of-a-dollar-in-every-state/" rel="canonical"/>
#   <meta content="https://www.usatoday.com/story/money/economy/2018/05/10/cost-of-living-value-of-dollar-in-every-state/34567549/" property="og:url"/>
#   <meta content="USA TODAY" property="og:site_name"/>
#   <meta content="https://www.gannett-cdn.com/-mm-/ee0f301149bc1263bd57862fdbee99a349f9c25d/c=0-198-907-708/local/-/media/2018/05/04/USATODAY/usatsports/247WallSt.com-247WS-460988-0873aa10.jpg?width=907&amp;height=510&amp;fit=crop&amp;format=pjpg&amp;auto=webp" property="og:image"/>
#   <meta content="907" property="og:image:width"/>
#   <meta content="510" property="og:image:height"/>
#   <meta content="NOODP, NOYDIR" name="ROBOTS"/>
#   <meta content="notranslate" name="google"/>
#   <meta content="article" property="og:type"/>
#   <script>
#    "use strict";{const c=window.FontFace,b=document,d="url(data:application/font-woff2;charset=utf-8;base64,...) format('woff2')";
# if(c){const a=new c("Unify Sans",d,{display:"optional",weight:"700"});a.load();b.fonts.add(a)}else{const a=b.createElement("style");a.innerHTML='@font-face{font-family:"Unify Sans";src:'+d+";font-display:optional;font-weight:700}";b.head.appendChild(a)}};
# {const c=window,a=navigator,e=a.userAgent,b={};c.gnt={u:{},v:{},a7s:{dq:[],tq:[]},now:Date.now(),bn:{}};;b.t=(b.ip=b.i=1<a.maxTouchPoints&&e.includes("c OS X"))||(b.tn=(b.a=
# e.includes("; And"))||(b.in=b.i=e.includes("(iP")));;c.g$={run:[],aeld:EventTarget.prototype.addEventListener,cached:{windowInnerHeight:innerHeight,windowInnerWidth:innerWidth},b,nv:a,ua:e,vv:c.visualViewport,el:{debounce:function(d){let q=-250,f;return function(a){if(!f){const b=a.timeStamp-q;250<b?(q=a.timeStamp,d(a)):f=setTimeout(()=>{f=0;q+=250;d(a)},250-b)}}}},intersectionObserverSupported:"IntersectionObserverEntry"in c&&"isIntersecting"in IntersectionObserverEntry.prototype}}
# try{window.localStorage&&(gnt.storage=!0)}catch(c){}
# (function(){function c(a,e){let b={};if(a&&"string"===typeof a){e||(e="&");let c=a.charCodeAt(0);var d=0;let f;if("&"===e){if(63===c||35===c)d=1;for(;a.charAt(d)===e;)++d}for(;;){for(;" "===a.charAt(d);)++d;c=a.indexOf("=",d);let h=a.indexOf(e,d);if(0<c&&(c<h||-1===h))if(d=a.substring(d,c),0<h)for(b[d]=a.substring(c+1,d=h);a.charAt(++d)===e;);else{b[d]=a.substr(c+1);break}else if(0<h&&(h<c||-1===c))for(b[a.substring(d,h)]=!0,d=h+1;(f=a.charAt(d))===e||" "===f;)++d;else{d<a.length&&(b[a.substr(d)]=
# !0);break}}}return b}g$.parseQS=c;g$.hp=g$.hashParams=c(location.hash);g$.qsp=g$.qsParams=c(location.search);g$.ic=g$.initCookies=c(document.cookie,";")})();;
# if(g$.b.t&&!g$.hp["gnt-disable-vu"]){let c;const a=g$.vv,e=function(b){(c||(c=document.querySelector("meta[name=viewport]"))).content="width="+b};if(a&&g$.b.a){let b="device-width";a.addEventListener("resize",function(){var d=Math.round(a.width*a.scale);d=1024>=d?1024:1200<=d?1200:"device-width";b!==d&&e(b=d)})}else(1024>screen.width||1024>screen.height)&&e(1024)};;
# gnt.luxEnabled=performance.mark&&(.04>Math.random()||g$.hp["gnt-enable-lux"])&&!g$.hp["gnt-disable-lux"];(g$.ut=performance.mark&&(gnt.luxEnabled||g$.hp["gnt-perf"])?c=>{performance.mark(c)}:()=>{})("gnt head");
# {const c=g$,{hp:a,ic:e}=c,{"gnt-user-cookiesMissing":b,"gnt-user-status":d,"gnt-user-ccpaout":q}=a,f=e.gup_lng,h=gnt,g=h.u;let k;if(f)try{k=g.lng=JSON.parse(decodeURIComponent(f))}catch(D){}k||(k=h.u.lng={auth:!1,hma:!1,lic:"none",name:"","ret-sub":!1,"ret-user":!1,nfc:!0});const u=document,m=u.documentElement,n=m.classList,x=d&&"string"===typeof d,y="sub"===d,z=y||"reg"===d,B=!(g.cm="boolean"===typeof b?b:!e.gup_lsid&&!z),l=g.au=x?z:B&&k.auth,C=g.hma=x?y:l&&k.hma,p=g.lt=a["gnt-user-licensetype"]||
# k.lic,A=g.wn=a["gnt-user-welcomename"]||k.name;g.rs=a["gnt-user-retsub"]||k["ret-sub"];g.ru=k["ret-user"];;g.rs&&(n.add("gnt__hnb"),h.hnb=!0);if((g.su="scroll0"in e)||l&&p&&p.endsWith("plus"))h.hnb=g.adfree=!0,n.add("gnt__hx","gnt__hnb");;l&&A&&(m.style.setProperty("--gnt-uwn","'"+A+"'"),m.setAttribute("data-u-n",""));m.setAttribute("data-u-s",g.s=l?C?"sub":"reg":"anon");;if(!a["gnt-disable-ccpa"]){let a,b,d=";path=/;secure;samesite=lax;max-age=31536000",
# c=e.OptanonConsent,f=e.usprivacy;if(h.storage){const a=localStorage,b=a.getItem("gnt.u.oc");if(!c&&b)u.cookie="OptanonConsent="+(c=b)+";domain=usatoday.com"+d;else if(c&&c!==b)try{a.setItem("gnt.u.oc",c)}catch(w){}}const k=Object.defineProperty,l=c&&c.length&&(-1<c.indexOf("on=US%3BCA")||-1<c.indexOf("on=US%3BNV"))?-1<(a=c.indexOf("groups="))&&(-1<(a="%2C"+c.substr(a+7)).indexOf("%2C4%3A0")||-1<a.indexOf("%2C5%3A0"))?2:1:0,m=g.co=q||2===l||f&&f[2]&&"Y"===f[2].toUpperCase(),p=function(t,
# F,w){if("getUSPData"===t&&"function"===typeof w)try{w({uspString:b,version:1},!0)}catch(G){}},n=function(){u.cookie="usprivacy="+b+d};f!==(b=l||f&&"1---"!==f?m?"1YYY":"1YNY":"1---")&&n();try{k(h,"usp",{enumerable:!0,get:function(){return b},set:function(t){b===t||q||(g.co="1YYY"===(b=t),n())}}),k(window,"__uspapi",{enumerable:!0,value:p})}catch(t){}}}
#   (g$.nv.share||g$.hp["gnt-enable-shareapi"])&&document.documentElement.setAttribute("data-ss-sa","");
#
#
#   document.documentElement.classList.remove("gnt__njs");
#
# ;;
# try{Object.defineProperty(window,"_sp_",{value:{config:{account_id:308}}})}catch(c){};
#   </script>
#   <style>
#    @font-face{font-family:'Unify Sans';src:local('☺︎')}@media not all and (min-resolution:.001dpcm){@media{@font-face{font-family:'Unify Sans';src:local('Helvetica Neue')}}}html{margin:0;padding:0;background:#fff;-webkit-text-size-adjust:none;text-size-adjust:none}body{margin:0;padding:0;background:unset;font:10px/13px 'Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif}img:not([src]):not([srcset]){visibility:hidden}img:-moz-loading{visibility:hidden}:focus{outline-color:#0098fe}.gnt_cw{display:flex;flex-wrap:wrap;align-items:stretch;width:980px;margin:20px auto 0;padding:0 10px;flex-shrink:0;position:relative;background:#fff}.gnt_pr{width:660px;margin-right:auto}.gnt_rr{contain:layout;overflow-anchor:none;width:300px;--gnt-x-nbh:80px}@media (min-width:1200px){.gnt_cw{width:1020px;margin:30px auto 0;padding:0 60px}}.gnt_ar_hl{margin:6px 0 0;color:#303030;font:700 36px/38px 'Unify Sans','Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif}.gnt_cw_w{isolation:isolate;display:flex;min-width:1000px}.gnt_cw_sl{overflow-anchor:none;flex:1;outline:0}.gnt_bc{min-width:1000px;height:20px;margin:0 0 -20px;background:linear-gradient(150deg,#00553c,50%,#3cc37d)}.gnt_xbr{display:none}@media (min-width:1200px){.gnt_bc{height:480px;margin:0 0 -480px}.gnt_xbr{overflow-anchor:none;display:block;width:0}.gnt_ar_xb{display:inline-block;position:-webkit-sticky;position:sticky;top:267px;transform:translate(36px,-58px);width:36px;height:36px;margin:0 0 -17px;border:4px solid #fff;border-radius:50%;background:#303030}.gnt__hx .gnt_ar_xb{transform:translate(36px,-92px)}.gnt__hnb .gnt_ar_xb{top:187px}.gnt_ar_xb::before{content:'';position:absolute;top:17px;left:10px;transform:rotate(45deg);width:16px;height:2px;background:#fff}.gnt_ar_xb::after{content:'';position:absolute;top:17px;left:10px;transform:rotate(-45deg);width:16px;height:2px;background:#fff}.gnt_ar_xb:hover{background:#000}}html:not(.gnt__njs) .gnt__hbd{display:none;background:unset}.gnt_ft{width:880px;height:722px;margin:-10px auto 0;padding:0 10px;color:#303030;-webkit-user-select:none;user-select:none}.gnt_ft_lw{display:flex;justify-content:space-between;margin:56px 0 -513px}.gnt_ft_ls{display:flex;flex-flow:column;width:150px}.gnt_ft_ls::before{content:attr(aria-label);margin:0 0 -1px;font:700 14px/16px 'Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif}.gnt_ft_a{margin:16px auto 0 -2px;padding:0 2px;color:#303030;font:14px/18px 'Georgia Pro',Georgia,'Droid Serif',serif;text-decoration:none}.gnt_ft_a:hover{color:#000}.gnt_ft_a__b{font-weight:700}.gnt_ft_cr{margin:542px 0 58px;font:12px/14px 'Georgia Pro',Georgia,'Droid Serif',serif;text-align:center}@media (min-width:1200px){.gnt_ft{padding:0 60px}}.gnt_x{margin:46px auto}.gnt_x_sl{contain:content;transform:translate3d(0,0,0);width:300px;min-height:250px;background-color:#f8f8f8;margin:auto;position:relative}.gnt_x__lbl::before{content:var(--gnt-x-lbl, 'Advertisement');text-align:center;color:#787878;font:10px/18px 'Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif;display:block}.gnt_x__st{position:-webkit-sticky;position:sticky;top:200px;margin-top:32px}.gnt__hnb .gnt_x__st{top:120px}.gnt_x_sl__st{transform:unset;will-change:unset}.gnt_x_lb{contain:strict;overflow:hidden;transform:translate3d(0,0,0);width:728px;height:90px;background-color:#f8f8f8;margin:auto}.gnt__hx .gnt_tb,.gnt__hx .gnt_x{display:none}.gnt_x__hi{contain:layout;margin:6px auto 18px;padding:0;--gnt-x-lbl:'Advertisement - scroll for more content'}.gnt_x_hi{width:970px;height:250px;display:flex;align-items:center;justify-content:center}.gnt_x_hi_bk{border:0;left:0;position:absolute;width:100%;height:100%;background-color:#fff}.gnt_x_hi_fc{position:relative}.gnt_x_hi__wd{height:initial;width:1140px;background-color:#fff}.gnt_x__pf{margin:0 auto 32px}.gnt_x_p{contain:layout}.gnt_x__al{margin:14px auto 32px;height:408px;clear:both}.gnt_x_al{width:initial;background-color:unset;height:390px;display:flex;align-items:center;justify-content:center;flex-d ...
#   </style>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="https://www.gannett-cdn.com/-mm-/ee0f301149bc1263bd57862fdbee99a349f9c25d/c=0-198-907-708/local/-/media/2018/05/04/USATODAY/usatsports/247WallSt.com-247WS-460988-0873aa10.jpg?width=907&amp;height=453&amp;fit=crop&amp;format=pjpg&amp;auto=webp" name="twitter:image"/>
#   <meta content="@usatoday" name="twitter:site"/>
#   <meta content="@usatoday" name="twitter:creator"/>
#   <meta content="Cost of living: The purchasing power of a dollar in every state" name="twitter:title"/>
#   <meta content="While a dollar bill looks and feels the same all over the United States, its value is often very different depending on where it is spent." name="twitter:description"/>
#  </head>
#  <body>
#   <svg style="display:none">
#    <symbol id="gnt_svg_external" viewbox="0 0 18 18">
#     <path d="M12.43 5.5H10.5V4H15v4.5h-1.5V6.55l-4.56 4.56-1.06-1.06 4.55-4.55zm1.07 9v-3.75H15V16H3V4h5.25v1.5H4.5v9h9z">
#     </path>
#    </symbol>
#    <svg id="gnt_svg_share_facebook" style="fill:var(--gnt-sfc,#4460a0)" viewbox="0 0 24 24">
#     <path d="M10.5932 20.9998C6.291 20.3204 3 16.5743 3 12.055 3 7.054 7.0294 3 12 3s9 4.054 9 9.0549c0 4.5198-3.2914 8.266-7.5943 8.9451v-6.3188h2.097l.3991-2.6175h-2.496v-1.6985c0-.716.3486-1.414 1.4666-1.414h1.1349V6.7227s-1.03-.1769-2.0146-.1769c-2.0558 0-3.3995 1.2536-3.3995 3.523v1.9948H8.3081v2.6175h2.2851v6.3186z">
#     </path>
#    </svg>
#    <symbol id="gnt_svg_share_twitter" style="fill:var(--gnt-sfc,#00aaec)" viewbox="0 0 24 24">
#     <path d="M21 6.776a7.213 7.213 0 0 1-2.12.596 3.778 3.778 0 0 0 1.623-2.095 7.273 7.273 0 0 1-2.346.918A3.642 3.642 0 0 0 15.462 5c-2.038 0-3.692 1.696-3.692 3.787 0 .296.032.585.095.862-3.069-.158-5.79-1.664-7.612-3.958a3.856 3.856 0 0 0-.5 1.906c0 1.313.652 2.472 1.643 3.152a3.626 3.626 0 0 1-1.673-.473v.047c0 1.835 1.273 3.366 2.963 3.713-.31.089-.636.133-.973.133-.238 0-.47-.023-.695-.067.47 1.504 1.833 2.599 3.45 2.628A7.292 7.292 0 0 1 3 18.3 10.282 10.282 0 0 0 8.66 20c6.794 0 10.508-5.77 10.508-10.774 0-.164-.003-.329-.01-.49A7.58 7.58 0 0 0 21 6.776">
#     </path>
#    </symbol>
#    <symbol id="gnt_svg_share_email" style="fill:var(--gnt-sfc,#626262)" viewbox="0 0 24 24">
#     <path d="M3 5.88c0-.49.4-.88.9-.88h16.2c.5 0 .9.4.9.88v12.24c0 .49-.4.88-.9.88H3.9a.9.9 0 0 1-.9-.88V5.88zm9 5.21L3 6.74v1.74l9 4.35 9-4.35V6.74l-9 4.35z">
#     </path>
#    </symbol>
#    <symbol id="gnt_svg_shareapi" style="fill:var(--gnt-sfc,#000)" viewbox="0 0 24 24">
#     <path d="M14 5l6 7-6 7V5zm0 4v6c-1.937-.271-3.937.062-6 1s-3.73 2.271-5 4c.909-3.576 2.242-6.242 4-8s4.091-2.758 7-3z">
#     </path>
#    </symbol>
#    <symbol id="gnt_svg_video_play" viewbox="0 0 84 84">
#     <circle cx="40.5" cy="40.5" fill="#303030" r="38" stroke="#0098FE" stroke-width="4">
#     </circle>
#     <path d="M56 40.23l-22.5 13.5v-27z" fill="#FFF">
#     </path>
#    </symbol>
#   </svg>
#   <header class="gnt_n" onmousedown="event.stopPropagation()" onmouseup="event.stopPropagation()">
#    <div class="gnt_n_lg_w">
#     <button aria-label="Skip to main content" class="gnt_n_sb" data-g-r="base_sb" data-t-l="${tc}|H1Nav|skipToMainContent">
#     </button>
#     <a aria-label="USA TODAY" class="gnt_n_lg" data-t-l="|H1Nav|logo" href="/">
#      <svg class="gnt_n_lg_svg" viewbox="0 2 78 28">
#       <circle cx="14" cy="16" fill="#009bff" r="14">
#       </circle>
#       <path d="M36 12.75a1.53 1.53 0 0 0 1.18-.45 1.82 1.82 0 0 0 .38-1.3V5.43h2.53V11A3.7 3.7 0 0 1 39 13.85a4.29 4.29 0 0 1-3 1 4.28 4.28 0 0 1-3-1A3.7 3.7 0 0 1 31.84 11V5.43h2.53V11a1.81 1.81 0 0 0 .42 1.28 1.52 1.52 0 0 0 1.21.47zm9.14 2.11a6.09 6.09 0 0 1-2.14-.39 5.26 5.26 0 0 1-1.8-1.11l1.22-1.54a4.17 4.17 0 0 0 1.22.77 3.89 3.89 0 0 0 1.5.28 1.64 1.64 0 0 0 .86-.19.63.63 0 0 0 .31-.57.67.67 0 0 0-.37-.59 5.35 5.35 0 0 0-1.3-.52l-.57-.15a4 4 0 0 1-1.9-1 2.35 2.35 0 0 1-.65-1.71 2.65 2.65 0 0 1 .48-1.5 3 3 0 0 1 1.28-1 4.64 4.64 0 0 1 1.89-.36 5.38 5.38 0 0 1 2 .39 5.82 5.82 0 0 1 1.71 1.03l-1.26 1.59a5.07 5.07 0 0 0-1.15-.73 3 3 0 0 0-1.31-.31 1.58 1.58 0 0 0-.84.18A.6.6 0 0 0 44 8a.7.7 0 0 0 .31.56 3.15 3.15 0 0 0 1.08.44l.69.19a4.25 4.25 0 0 1 2.11 1.12 2.42 2.42 0 0 1 .62 1.65 2.65 2.65 0 0 1-.46 1.54 3 3 0 0 1-1.29 1 4.73 4.73 0 0 1-1.92.36zm11.32-.18L55.87 13h-3.46l-.58 1.73h-2.5l3.39-9.25h2.94l3.34 9.2zM53 11.08h2.19l-1.04-3.24zM34.59 26.53v-7.21h-2.75v-2h8v2h-2.72v7.21zM45.16 26.71a4.92 4.92 0 0 1-2.47-.61A4.49 4.49 0 0 1 41 24.4a4.87 4.87 0 0 1-.63-2.48 5.15 5.15 0 0 1 .34-1.92 4.48 4.48 0 0 1 1-1.52 4.61 4.61 0 0 1 1.52-1 5.38 5.38 0 0 1 3.83 0 4.62 4.62 0 0 1 1.52 1 4.47 4.47 0 0 1 1 1.52 5.13 5.13 0 0 1 .42 1.92 4.87 4.87 0 0 1-.62 2.48 4.49 4.49 0 0 1-1.71 1.69 4.92 4.92 0 0 1-2.51.62zm0-2.09a2 2 0 0 0 1.16-.34 2.3 2.3 0 0 0 .78-.95 3.26 3.26 0 0 0 .29-1.41 3.31 3.31 0 0 0-.29-1.41 2.35 2.35 0 0 0-.78-1 2.12 2.12 0 0 0-2.33 0 2.35 2.35 0 0 0-.78 1 3.31 3.31 0 0 0-.29 1.41 3.26 3.26 0 0 0 .29 1.41 2.3 2.3 0 0 0 .78.95 2 2 0 0 0 1.17.33zm6.25 1.91v-9.25h3.65a4.88 4.88 0 0 1 2.43.59 4.31 4.31 0 0 1 1.65 1.63 5.12 5.12 0 0 1 0 4.8 4.31 4.31 0 0 1-1.65 1.63 4.88 4.88 0 0 1-2.43.59zm2.49-2h1.16a1.91 1.91 0 0 0 1.57-.72 3 3 0 0 0 .58-1.9 3 3 0 0 0-.58-1.9 1.91 1.91 0 0 0-1.57-.72H53.9zm13.3 2l-.58-1.73h-3.47l-.58 1.73h-2.5l3.39-9.25h2.94l3.39 9.25zm-3.41-3.6H66l-1.09-3.24zm10.88.27v3.33H72.1V23.2l-3.28-5.92h2.86L73.39 21l1.7-3.67h2.86z" fill="#404040">
#       </path>
#      </svg>
#     </a>
#    </div>
#    <div class="gnt_n_fl gnt_n_nc__hbn">
#     <a class="gnt_n_fl_l" data-c-lbl="CASHING IN ON COVID-19" data-t-l="|top-flag1|money|Cashing in on COVID-19|Stem cell firms sell…" href="/story/money/business/2020/06/22/stem-cell-companies-selling-hope-unproven-treatments-covid-19/5348246002/">
#      Stem cell firms sell hope
#     </a>
#     <a class="gnt_n_fl_l" data-c-lbl="BLACK-OWNED BUSINESSES" data-t-l="|top-flag2|money|Black-owned businesses|Customer support surges" href="/story/money/2020/06/23/black-owned-businesses-see-surge-interest-amid-race-protests/3207595001/">
#      Customer support surges
#     </a>
#     <a class="gnt_n_fl_l" data-c-lbl="SUMMER INTERRUPTED" data-t-l="|top-flag3|money|Summer interrupted|Teens can't find ☀ jobs" href="/in-depth/money/2020/06/22/unemployment-teenagers-struggle-find-summer-jobs-during-covid-19/3133617001/">
#      Teens can't find ☀ jobs
#     </a>
#     <a class="gnt_n_fl_l gnt_n_fl_l__li" data-c-lbl="CORONAVIRUS SHORTAGES" data-t-l="|top-flag4|money|Coronavirus shortages|Coins tougher to find" href="/story/money/2020/06/20/coronavirus-shortage-coin-supply-pennies-nickels-dimes-quarters/3230828001/">
#      Coins tougher to find
#     </a>
#    </div>
#    <div class="gnt_n_sm gnt_n_nc__hbn">
#     <a class="gnt_n_sm_a" data-t-l="|H1Nav|headersubscribecallout" data-u-sr="anon reg" elementtiming="nav-submsg" href="https://subscribe.usatoday.com/aboffer?gps-source=CPMASTHEAD&amp;utm_campaign=2020JULY4&amp;utm_medium=ONSITE&amp;onSuccessRedirectURL=https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Feconomy%2F2018%2F05%2F10%2Fcost-of-living-value-of-dollar-in-every-state%2F34567549%2F" rel="noopener" target="_blank">
#      <div class="gnt_n_sm_a_pt">
#       SUBSCRIBE NOW
#      </div>
#      $2 for 2 months
#     </a>
#    </div>
#    <nav aria-label="Global navigation" class="gnt_n_mn">
#     <a class="gnt_n_mn_l gnt_n_mn_l__fi gnt_n_mn_ce" data-t-l="|H1Nav|news" elementtiming="nav-item" href="/news/">
#      News
#     </a>
#     <a class="gnt_n_mn_l gnt_n_mn_ce" data-t-l="|H1Nav|sports" href="/sports/">
#      Sports
#     </a>
#     <a class="gnt_n_mn_l gnt_n_mn_ce" data-t-l="|H1Nav|entertainment" href="/entertainment/">
#      Entertainment
#     </a>
#     <a class="gnt_n_mn_l gnt_n_mn_ce" data-t-l="|H1Nav|life" href="/life/">
#      Life
#     </a>
#     <a class="gnt_n_mn_l gnt_n_mn_ce gnt_n_mn_l__se" data-t-l="|H1Nav|money" href="/money/">
#      Money
#     </a>
#     <a class="gnt_n_mn_l gnt_n_mn_ce" data-t-l="|H1Nav|tech" href="/tech/">
#      Tech
#     </a>
#     <a class="gnt_n_mn_l gnt_n_mn_ce" data-t-l="|H1Nav|travel" href="/travel/">
#      Travel
#     </a>
#     <a class="gnt_n_mn_l gnt_n_mn_ce" data-t-l="|H1Nav|opinion" href="/opinion/">
#      Opinion
#     </a>
#     <div class="gnt_n_dd_w" data-g-r="nav_ce nav_sh">
#      <button aria-expanded="false" aria-haspopup="true" aria-label="Global Navigation" class="gnt_n_dd_bt gnt_n_mn_ce" data-g-ltn="navgd" data-g-r="nav_ab" data-g-tn="navgdp" data-t-l="${tc}|H1Nav|caret">
#       <svg class="gnt_n_dd_bt_svg" viewbox="0 0 10 6">
#        <path d="M5 3.35L8.64 0 10 1.4 5 6 0 1.4 1.36 0z">
#        </path>
#       </svg>
#      </button>
#     </div>
#     <div class="gnt_n_us">
#      <div class="gnt_n_se" data-g-r="nav_ce">
#       <a aria-expanded="false" aria-haspopup="true" aria-label="Search" class="gnt_n_se_a gnt_n_mn_ce" data-g-r="nav_ab" data-g-tn="navse" data-t-l="${tc}|H1Nav|search" href="/search/" title="Search">
#        <svg class="gnt_n_se_a_svg" viewbox="0 0 24 24">
#         <path d="M15.75 14.33l4.96 4.96-1.42 1.42-4.96-4.96a6.5 6.5 0 1 1 1.41-1.41zM10.5 15a4.5 4.5 0 1 0 0-9 4.5 4.5 0 0 0 0 9z">
#         </path>
#        </svg>
#       </a>
#      </div>
#      <a class="gnt_n_us_sb" data-t-l="|H1Nav|subscribe" data-u-sr="anon reg" elementtiming="nav-subbt" href="https://subscribe.usatoday.com/aboffer?gps-source=CPTOPNAVBAR&amp;utm_campaign=2020JULY4&amp;utm_medium=ONSITE&amp;onSuccessRedirectURL=https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Feconomy%2F2018%2F05%2F10%2Fcost-of-living-value-of-dollar-in-every-state%2F34567549%2F" rel="noopener" target="_blank">
#       Subscribe
#      </a>
#      <div class="gnt_n_us_a_w" data-g-r="nav_ce">
#       <a aria-expanded="false" aria-haspopup="true" aria-label="Sign In" class="gnt_n_us_a gnt_n_mn_ce" data-g-r="nav_ab" data-g-tn="navus" data-t-l="${tc}|H1Nav|account" href="https://login.usatoday.com/USAT-GUP/authenticate?success-url=https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Feconomy%2F2018%2F05%2F10%2Fcost-of-living-value-of-dollar-in-every-state%2F34567549%2F&amp;cancel-url=https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Feconomy%2F2018%2F05%2F10%2Fcost-of-living-value-of-dollar-in-every-state%2F34567549%2F">
#        <svg class="gnt_n_us_a_svg" viewbox="0 0 10 6">
#         <path d="M5 3.35L8.64 0 10 1.4 5 6 0 1.4 1.36 0z">
#         </path>
#        </svg>
#       </a>
#      </div>
#     </div>
#    </nav>
#   </header>
#   <aside aria-label="advertisement" class="gnt_m gnt_x gnt_x__nb" data-x-fc="gnt_x_nbf" data-x-src="https://securepubads.g.doubleclick.net/gampad/adx?t=position%3Dconsumer_sales-nano_bar&amp;iu=7103%2Fusatoday%2Fconsumer_sales-nano_bar%2Fmoney&amp;sz=1025x80&amp;cust_params=cst_section%3Dmoney%26pageType%3Dstory%26contentid%3D34567549%26property%3DUSAT%26sitepage%3DUSAT%2Fstory%26ssts_section%3Dmoney%26ssts_subsection%3Deconomy%26topic%3Dcost-of-living%2Ceconomy" data-x-sx="consumer_sales-nano_bar">
#   </aside>
#   <aside aria-label="advertisement" class="gnt_m gnt_x gnt_x__lbl gnt_x__hi">
#    <div class="gnt_x_sl gnt_x_hi" id="ad-slot-7103-usatoday-high_impact-money-1">
#    </div>
#   </aside>
#   <div class="gnt_bc">
#   </div>
#   <div class="gnt_cw_w">
#    <a aria-hidden="true" aria-label="Close" class="gnt_cw_sl" data-g-r="base_xbutton" data-t-l="|modalclose|overlay" href="/money/" tabindex="-1">
#    </a>
#    <main class="gnt_cw">
#     <div aria-label="Economy" class="gnt_ar_lbl" data-c-ssts="ECONOMY">
#     </div>
#     <article class="gnt_pr">
#      <h1 class="gnt_ar_hl" elementtiming="ar-headline">
#       Cost of living: The purchasing power of a dollar in every state
#      </h1>
#      <div class="gnt_ar_by">
#       Michael B. Sauter
#      </div>
#      <div class="gnt_ar_pb">
#       24/7 Wall Street
#      </div>
#      <div aria-label="Published 8:00 a.m. ET May 10, 2018" class="gnt_ar_dt">
#      </div>
#      <div class="gnt_ss" data-g-r="base_sc" data-ss-d="While a dollar bill looks and feels the same all over the United States, its value is often very different depending on where it is spent." data-ss-t="Cost of living: The purchasing power of a dollar in every state" data-ss-u="https://www.usatoday.com/story/money/economy/2018/05/10/cost-of-living-value-of-dollar-in-every-state/34567549/">
#       <a aria-label="Share to Facebook" class="gnt_ss_a" data-g-r="base_si" data-ss-a="f" data-t-l="${tc}|navbar-share-top|facebook" href="https://www.facebook.com/dialog/share?display=popup&amp;app_id=215046668549694&amp;href=https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Feconomy%2F2018%2F05%2F10%2Fcost-of-living-value-of-dollar-in-every-state%2F34567549%2F">
#        <svg class="gnt_ss_a_svg">
#         <use xlink:href="#gnt_svg_share_facebook">
#         </use>
#        </svg>
#       </a>
#       <a aria-label="Share to Twitter" class="gnt_ss_a" data-g-r="base_si" data-ss-a="t" data-t-l="${tc}|navbar-share-top|twitter" href="http://twitter.com/share?url=https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Feconomy%2F2018%2F05%2F10%2Fcost-of-living-value-of-dollar-in-every-state%2F34567549%2F&amp;text=Cost%20of%20living%3A%20The%20purchasing%20power%20of%20a%20dollar%20in%20every%20state&amp;via=usatoday">
#        <svg class="gnt_ss_a_svg">
#         <use xlink:href="#gnt_svg_share_twitter">
#         </use>
#        </svg>
#       </a>
#       <a aria-label="Share by email" class="gnt_ss_a" data-t-l="${tc}|navbar-share-top|email" href="mailto:?subject=Cost%20of%20living%3A%20The%20purchasing%20power%20of%20a%20dollar%20in%20every%20state%20-%20from%20USA%20TODAY&amp;body=Cost%20of%20living%3A%20The%20purchasing%20power%20of%20a%20dollar%20in%20every%20state%0A%0AWhile%20a%20dollar%20bill%20looks%20and%20feels%20the%20same%20all%20over%20the%20United%20States%2C%20its%20value%20is%20often%20very%20different%20depending%20on%20where%20it%20is%20spent.%0A%0ACheck%20out%20this%20story%20on%20usatoday.com%3A%20https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Feconomy%2F2018%2F05%2F10%2Fcost-of-living-value-of-dollar-in-every-state%2F34567549%2F">
#        <svg class="gnt_ss_a_svg">
#         <use xlink:href="#gnt_svg_share_email">
#         </use>
#        </svg>
#       </a>
#       <button aria-label="Share natively" class="gnt_ss_a gnt_ss_a__sa" data-g-r="base_si" data-ss-a="s" data-t-l="${tc}|navbar-share-top|shareapi">
#        <svg class="gnt_ss_a_svg">
#         <use xlink:href="#gnt_svg_shareapi">
#         </use>
#        </svg>
#       </button>
#      </div>
#      <div class="gnt_ar_b">
#       <aside aria-label="Video - How much money you need to earn to be considered rich in these cities" class="gnt_em gnt_em__fp gnt_em_vp__tp gnt_em__el">
#        <div aria-live="polite" class="gnt_em_vp_w" data-c-vt="teal" data-g-r="vp_tp" data-t-pl="teal-hero">
#         <button aria-label="Play video" class="gnt_em_vp_a gnt_em_vp__tp_a" data-c-vpattrs='{"muted":true,"xprp":1,"bContent":false,"an":"usatoday","pn":"USA TODAY","vidNum":1,"docking":true}' data-c-vpdata='{"adsEnabled":true,"awsPath":"money","byline":"Buzz60","canonicalURL":"","contentSourceCode":"BZ60","createDate":"2018-02-27T13:17:23.817Z","credit":"Buzz60","duration":86698,"headline":"","hlsURL":"","id":"110885214","image":{"url":"http://www.gannett-cdn.com/-mm-/621b37bf60a76adf00ec82d1926457b31d7ab3b6/c=0-30-580-356&amp;r=1280x720/local/-/media/2018/02/24/USATODAY/usatsports/large-pile-of-hundred-dollar-bills-cash-money-savings-rich_large.jpg","opto":true},"initialPublishDate":"2018-02-27T13:27:17.587Z","keywords":"Simply Money,Cities","mp4URL":"https://media.gannett-cdn.com/29906170001/29906170001_5741306034001_5741306116001.mp4","origin":"Buzz60","pageURL":{"long":"https://www.usatoday.com/videos/money/2018/02/27/how-much-money-you-need-earn-considered-rich-these-cities/110885214/"},"promoBrief":"The Business Insider got a little more specific and analyzed data to figure out, how much exactly do you need to make in order to be considered rich in these top US cities. Susana Victoria Perez (@susana_vp) has more.","publishDate":"2018-02-27T13:27:17.587Z","series":"","ssts":{"section":"money","subsection":"","topic":"","subtopic":""},"tags":[{"id":"1660aeab-4a3d-4952-9733-0381dab75157","name":"Cities"},{"id":"34b6a1e2-fa92-4d95-a1a0-89d20bc5ca74","name":"Simply Money"}],"title":"How much money you need to earn to be considered rich in these cities","url":"/videos/money/2018/02/27/how-much-money-you-need-earn-considered-rich-these-cities/110885214/"}' data-g-r="vp_ap vp_tg">
#          <img alt="" class="gnt_em_vp_img" data-g-r="vp_po" decoding="async" elementtiming="ar-lead-image" src="http://www.gannett-cdn.com/-mm-/621b37bf60a76adf00ec82d1926457b31d7ab3b6/c=0-30-580-356&amp;r=1280x720/local/-/media/2018/02/24/USATODAY/usatsports/large-pile-of-hundred-dollar-bills-cash-money-savings-rich_large.jpg?width=660&amp;height=371&amp;fit=crop&amp;format=pjpg&amp;auto=webp"/>
#          <svg class="gnt_em_vp_svg">
#           <use xlink:href="#gnt_svg_video_play">
#           </use>
#          </svg>
#         </button>
#         <div class="gnt_em_vp_c">
#          <button aria-label="Close docked video player" class="gnt_em_vp_db" data-t-l="${tc}|tealplayer|playerClose">
#           <svg viewbox="0 0 16 16">
#            <path d="M9 7.625L13.125 3.5 14.5 4.875 10.375 9l4.125 4.125-1.375 1.375L9 10.375 4.875 14.5 3.5 13.125 7.625 9 3.5 4.875 4.875 3.5 9 7.625z">
#            </path>
#           </svg>
#          </button>
#         </div>
#        </div>
#        <div class="gnt_em_vt" data-c-et="How much money you need to earn to be considered rich in these cities">
#        </div>
#        <div aria-label="The Business Insider got a little more specific and analyzed data to figure out, how much exactly do you need to make in order to be considered rich in these top US cities. Susana Victoria Perez (@susana_vp) has more." class="gnt_em_vb gnt_em_vb__te" data-c-credit="Buzz60">
#        </div>
#       </aside>
#       <p class="gnt_ar_b_p">
#        While a dollar bill looks and feels the same all over the United States, its value is often very different depending on where it is spent.
#       </p>
#       <p class="gnt_ar_b_p">
#        The prices of housing, food, and services vary considerably across the country. To shed light on these differences that reflect the relative purchasing power of Americans in every state, 24/7 Wall St. calculated the value of a dollar in each using data from the Bureau of Economic Analysis.
#       </p>
#       <p class="gnt_ar_b_p">
#        The value of a dollar, of course, is higher in places where goods and services are less expensive. For the most part, the areas with a low cost of living are in the South. By contrast, the most expensive states -- where the dollar is worth the least -- are home to some of the nation’s largest urban clusters.
#       </p>
#       <aside aria-label="advertisement" class="gnt_m gnt_x gnt_x__lbl gnt_x__al">
#        <div class="gnt_x_sl gnt_x_al" data-g-r="lazy" data-gl-method="lazyLoadX" id="~ad-slot-7103-usatoday-native-article_link-money-2">
#        </div>
#       </aside>
#       <p class="gnt_ar_b_p">
#        Much of the differences between the states’ cost of living result from divergences in housing costs. For example, with Hawaii’s relatively high housing prices, a dollar spent on rent there is worth only 61 cents. A dollar spent on rent in Arkansas, on the other hand, delivers essentially $1.58 in value.
#       </p>
#       <p class="gnt_ar_b_p">
#        States with large shares of residents living in expensive housing within urban areas account for the vast majority of the states where a dollar is worth the least. A dollar is generally worth much more in states, particularly in the South, where a smaller share of residents live in cities.
#       </p>
#       <p class="gnt_ar_b_p">
#        <strong class="gnt_ar_b_al">
#         More:
#        </strong>
#        <a class="gnt_ar_b_a" data-t-l="|inline|intext|n/a" href="https://www.usatoday.com/story/money/personalfinance/2018/04/26/best-us-cities-older-americans-retire/550108002/">
#         Thinking about where to retire? Here are 30 great U.S. cities for older Americans
#        </a>
#       </p>
#       <figure class="gnt_em gnt_em_img">
#        <img alt="While a dollar bill looks and feels the same all over the United States, its value is often very different depending on where it is spent. The prices of housing, food, and services vary considerably across the country. To shed light on these differences that reflect the relative purchasing power of Americans in every state, [&amp;#8230;]" class="gnt_em_img_i" data-g-r="lazy" data-gl-src="https://www.gannett-cdn.com/-mm-/ee0f301149bc1263bd57862fdbee99a349f9c25d/c=0-198-907-708/local/-/media/2018/05/04/USATODAY/usatsports/247WallSt.com-247WS-460988-0873aa10.jpg?width=660&amp;height=372&amp;fit=crop&amp;format=pjpg&amp;auto=webp" decoding="async" style="height:372px"/>
#        <div class="gnt_em_img_ccw gnt_em_img_ccw__cap gnt_em_img_ccw__crd" data-c-caption="While a dollar bill looks and feels the same all over the United States, its value is often very different depending on where it is spent. The prices of housing, food, and services vary considerably across the country. To shed light on these differences that reflect the relative purchasing power of Americans in every state, [&amp;#8230;]" data-c-credit="Petr Kratochvil / Public Domain Pictures">
#        </div>
#       </figure>
#       <p class="gnt_ar_b_p">
#        <strong>
#         1. Alabama
#        </strong>
#       </p>
#       <p class="gnt_ar_b_p">
#       </p>
#       <ul class="gnt_ar_b_ul">
#        <li class="gnt_ar_b_ul_li">
#         <strong>
#          Value of a dollar:
#         </strong>
#         $1.15
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Personal income: $40,267 (12th lowest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Cost of living adjusted income: $46,055 (12th lowest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Median home value: $136,200 (7th highest)
#        </li>
#       </ul>
#       <p class="gnt_ar_b_p">
#       </p>
#       <p class="gnt_ar_b_p">
#        <strong>
#         2. Alaska
#        </strong>
#       </p>
#       <p class="gnt_ar_b_p">
#       </p>
#       <ul class="gnt_ar_b_ul">
#        <li class="gnt_ar_b_ul_li">
#         <strong>
#          Value of a dollar:
#         </strong>
#         $0.95
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Personal income: $48,973 (7th highest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Cost of living adjusted income: $53,070 (13th highest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Median home value: $267,800 (11th lowest)
#        </li>
#       </ul>
#       <p class="gnt_ar_b_p">
#       </p>
#       <figure class="gnt_em gnt_em_img">
#        <img alt="Arizona" class="gnt_em_img_i" data-g-r="lazy" data-gl-src="https://www.gannett-cdn.com/-mm-/24754b2f2e29acd0de721e6d1970b9845a25ca54/c=0-0-1356-766/local/-/media/2018/05/04/USATODAY/usatsports/247WallSt.com-247WS-460988-flu-arizona.jpg?width=660&amp;height=373&amp;fit=crop&amp;format=pjpg&amp;auto=webp" data-gl-srcset="https://www.gannett-cdn.com/-mm-/24754b2f2e29acd0de721e6d1970b9845a25ca54/c=0-0-1356-766/local/-/media/2018/05/04/USATODAY/usatsports/247WallSt.com-247WS-460988-flu-arizona.jpg?width=1320&amp;height=746&amp;fit=crop&amp;format=pjpg&amp;auto=webp 2x" decoding="async" style="height:373px"/>
#        <div class="gnt_em_img_ccw gnt_em_img_ccw__cap gnt_em_img_ccw__crd" data-c-caption="Arizona" data-c-credit="Tonda / IStock">
#        </div>
#       </figure>
#       <p class="gnt_ar_b_p">
#        <strong>
#         3. Arizona
#        </strong>
#       </p>
#       <p class="gnt_ar_b_p">
#       </p>
#       <ul class="gnt_ar_b_ul">
#        <li class="gnt_ar_b_ul_li">
#         <strong>
#          Value of a dollar:
#         </strong>
#         $1.04
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Personal income: $37,694 (6th lowest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Cost of living adjusted income: $43,278 (4th lowest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Median home value: $205,900 (22nd lowest)
#        </li>
#       </ul>
#       <p class="gnt_ar_b_p">
#       </p>
#       <p class="gnt_ar_b_p">
#        <strong>
#         4. Arkansas
#        </strong>
#       </p>
#       <p class="gnt_ar_b_p">
#       </p>
#       <ul class="gnt_ar_b_ul">
#        <li class="gnt_ar_b_ul_li">
#         <strong>
#          Value of a dollar:
#         </strong>
#         $1.14
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Personal income: $40,858 (14th lowest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Cost of living adjusted income: $46,672 (14th lowest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Median home value: $123,300 (3rd highest)
#        </li>
#       </ul>
#       <p class="gnt_ar_b_p">
#       </p>
#       <p class="gnt_ar_b_p">
#        <strong>
#         5. California
#        </strong>
#       </p>
#       <p class="gnt_ar_b_p">
#       </p>
#       <ul class="gnt_ar_b_ul">
#        <li class="gnt_ar_b_ul_li">
#         <strong>
#          Value of a dollar:
#         </strong>
#         $0.88
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Personal income: $44,173 (25th highest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Cost of living adjusted income: $51,386 (21st highest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Median home value: $477,500 (2nd lowest)
#        </li>
#       </ul>
#       <p class="gnt_ar_b_p">
#       </p>
#       <p class="gnt_ar_b_p">
#        <strong>
#         6. Colorado
#        </strong>
#       </p>
#       <p class="gnt_ar_b_p">
#       </p>
#       <ul class="gnt_ar_b_ul">
#        <li class="gnt_ar_b_ul_li">
#         <strong>
#          Value of a dollar:
#         </strong>
#         $0.97
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Personal income: $46,016 (20th highest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Cost of living adjusted income: $51,845 (19th highest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Median home value: $314,200 (5th lowest)
#        </li>
#       </ul>
#       <p class="gnt_ar_b_p">
#       </p>
#       <p class="gnt_ar_b_p">
#        <strong>
#         7. Connecticut
#        </strong>
#       </p>
#       <p class="gnt_ar_b_p">
#       </p>
#       <ul class="gnt_ar_b_ul">
#        <li class="gnt_ar_b_ul_li">
#         <strong>
#          Value of a dollar:
#         </strong>
#         $0.92
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Personal income: $57,520 (the highest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Cost of living adjusted income: $64,509 (the highest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Median home value: $274,600 (10th lowest)
#        </li>
#       </ul>
#       <p class="gnt_ar_b_p">
#       </p>
#       <p class="gnt_ar_b_p">
#        <strong>
#         8. Delaware
#        </strong>
#       </p>
#       <p class="gnt_ar_b_p">
#       </p>
#       <ul class="gnt_ar_b_ul">
#        <li class="gnt_ar_b_ul_li">
#         <strong>
#          Value of a dollar:
#         </strong>
#         $1.00
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Personal income: $42,917 (22nd lowest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Cost of living adjusted income: $48,929 (25th lowest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Median home value: $243,400 (16th lowest)
#        </li>
#       </ul>
#       <p class="gnt_ar_b_p">
#       </p>
#       <figure class="gnt_em gnt_em_img">
#        <img alt="St. Augustine-St. Johns County, Fla." class="gnt_em_img_i" data-g-r="lazy" data-gl-src="https://www.gannett-cdn.com/-mm-/b2b05a4ab25f4fca0316459e1c7404c537a89702/c=0-0-1365-768/local/-/media/2018/05/04/USATODAY/usatsports/247WallSt.com-247WS-460988-631c5a03.jpg?width=660&amp;height=372&amp;fit=crop&amp;format=pjpg&amp;auto=webp" data-gl-srcset="https://www.gannett-cdn.com/-mm-/b2b05a4ab25f4fca0316459e1c7404c537a89702/c=0-0-1365-768/local/-/media/2018/05/04/USATODAY/usatsports/247WallSt.com-247WS-460988-631c5a03.jpg?width=1320&amp;height=744&amp;fit=crop&amp;format=pjpg&amp;auto=webp 2x" decoding="async" style="height:372px"/>
#        <div class="gnt_em_img_ccw gnt_em_img_ccw__cap gnt_em_img_ccw__crd" data-c-caption="St. Augustine-St. Johns County, Fla." data-c-credit="Thinkstock">
#        </div>
#       </figure>
#       <p class="gnt_ar_b_p">
#        <strong>
#         9. Florida
#        </strong>
#       </p>
#       <p class="gnt_ar_b_p">
#       </p>
#       <ul class="gnt_ar_b_ul">
#        <li class="gnt_ar_b_ul_li">
#         <strong>
#          Value of a dollar:
#         </strong>
#         $1.01
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Personal income: $41,781 (18th lowest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Cost of living adjusted income: $47,093 (17th lowest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Median home value: $197,700 (23rd lowest)
#        </li>
#       </ul>
#       <p class="gnt_ar_b_p">
#       </p>
#       <p class="gnt_ar_b_p">
#        <strong>
#         10. Georgia
#        </strong>
#       </p>
#       <p class="gnt_ar_b_p">
#       </p>
#       <ul class="gnt_ar_b_ul">
#        <li class="gnt_ar_b_ul_li">
#         <strong>
#          Value of a dollar:
#         </strong>
#         $1.08
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Personal income: $40,540 (13th lowest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Cost of living adjusted income: $46,728 (15th lowest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Median home value: $166,800 (20th highest)
#        </li>
#       </ul>
#       <p class="gnt_ar_b_p">
#       </p>
#       <p class="gnt_ar_b_p">
#        <strong>
#         11. Hawaii
#        </strong>
#       </p>
#       <p class="gnt_ar_b_p">
#       </p>
#       <ul class="gnt_ar_b_ul">
#        <li class="gnt_ar_b_ul_li">
#         <strong>
#          Value of a dollar:
#         </strong>
#         $0.84
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Personal income: $37,634 (5th lowest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Cost of living adjusted income: $43,720 (7th lowest)
#        </li>
#        <li class="gnt_ar_b_ul_li">
#         Median home value: $592,000 (the lowest)
#        </li>
# ...
# {;let a=document.referrer,c=location.origin;if(a=0===a.indexOf(c)&&a.substr(c.length)){let b;(b=a.indexOf("?"))&&-1<b&&(a=a.substr(0,b));(b=a.indexOf("#"))&&-1<b&&(a=a.substr(0,b))}if("/"===a||"/news/"===a||"/sports/"===a||"/entertainment/"===a||"/money/"===a)setTimeout(function(){;gnt.addScript("https://c2.taboola.com/nr/usatodaydemo/newsroom.js",
# !0,function(){g$.ut("gnt tbhtCb")})});};{const a=gnt.u;a.getUser();if(a.au){const c=document.querySelector(".gnt_n_us_a");c&&(c.href="https://account."+gnt.data.publicationDomain,a.wn&&c.setAttribute("aria-label","Hi, "+a.wn));}}
# {const a=g$,c=a.vv,b=a.cached,f=a.el.debounce(()=>{b.windowInnerWidth=innerWidth;b.windowInnerHeight=innerHeight;for(const b of a.rh)b()});addEventListener("resize",f);c&&c.addEventListener("resize",f);a.rh=new Set};;
# g$.hp["gnt-disable-scrolljs"]||setTimeout(function(){function a(){const a=b.createElement("script"),n=g$.ua;a.crossOrigin="use-credentials";a.src="https://static.scroll.com/js/scroll"+(c||g$.b.i||-1===n.indexOf("Chrome")&&-1<n.indexOf("Safari")||-1<location.search.indexOf("scroll")?".js":"-smart.js");b.head.appendChild(a)}const c=gnt.u.su,b=document;window.Scroll={config:{detected:c},_q:c?[function(){function a(a){"number"!==typeof a||e===a&&h||(e=a,h||(h=b.querySelector('[title="Scroll features"]')),
# h&&(h.style.zIndex=e?9999998:2147483647));return e}let c=gnt.v,e=0,h;c.sbp&&setTimeout(a,c.sbp);Object.defineProperty(c,"sbp",{get:a,set:a})}]:[]};c?a():g$.run.push(a)});;gnt.tmpl={navgd:{url:"/global-q1a2z3C4M2nNlQYzWhCC0oMSEFjQbW1KA.min.json",fb:"<div data-g-r=nav_fm style='padding:32px 32px 0 0;font:700 20px/24px \"Unify Sans\",\"Helvetica Neue\",\"Arial Nova\",Helvetica,Arial,sans-serif'>The navigation could not be loaded.</div><div data-g-r=nav_fm style='padding:18px 32px 18px 0;font:16px/18px \"Helvetica Neue\",\"Arial Nova\",Helvetica,Arial,sans-serif'>Please check your internet connection and try again."}};;
# g$.hp["gnt-disable-anc"]||(g$.el.loadAnc=function(){function c(){f.gannett={atoms:{setup:{camId:g$.ic.cam_eid||"control",environment:d,gup_lng:a.lng,platform:"tangent",siteCode:"USAT",ssts:"money/economy",taxonomy:["Cost of living","Economy"],user:a.user,analytics:{newslettersignupcta:function(a){b?gnt.a7s.tq.push({et:"uotrack",ca:gnt.data.a7sPre+"|"+a}):b=1}}}}};g$.require({url:g,co:!0}).then(function(){const {FontFace:a,
# customElements:b}=f;a&&document.fonts.add(new a("Gannett Atoms Components Unify Serif","local(Georgia Pro),local(Georgia),local(Droid Serif)"));b&&b.define("gannett-atoms-component-ui-font-loader",class extends HTMLElement{connectedCallback(){this.style.display="none"}})})}const e=g$.preload,a=gnt.u,f=window,d="stage"===g$.hp["gnt-test-ancenv"]?"stage":"prod",h="https://atoms.usatoday.com",g=h+"/atoms-library/"+d+"/dist/gannett-atoms-library.js";let b;
# e(g,b,1);e(h+"/atoms-components/"+d+"/dist/gannett-atoms-components/gannett-atoms-components.esm.js",b,1);e("https://user.usatoday.com/USAT-GUP/user/newsletters/","fetch","use-credentials");a.user&&!a.user.local?c():a.getUser().then(c,c)});
#
#         if(0===document.referrer.indexOf(location.origin)){let b,d;for(let a=0,e=document.querySelectorAll("[data-g-r~=base_xbutton]"),f=e.length;a<f;a++)Object.defineProperty(e[a],"href",{configurable:!0,enumerable:!0,get:function(){if(!d){d=!0;const a=sessionStorage.previousFront;if(a)try{const c=JSON.parse(a);c&&(b=c.path)}catch(c){}}b&&this.setAttribute("href",b);Object.defineProperty(this,"href",{configurable:!0,enumerable:!0,value:b||this.getAttribute("href")})}})};
#
#
#   g$.run.push(function(){g$.registerMod("vp");;g$.hp["gnt-disable-autoplay"]||g$.el.trigger("vp_ap",document.documentElement);});
#
#
#   ;
# gnt.data.tVPS={vIas:"https://www.gannett-cdn.com/gannett-web/apps/teal/dist/vendor/ias/ias-3.5.1.min.js",vIma3:"https://imasdk.googleapis.com/js/sdkloader/ima3.js",vIIma:"https://www.gannett-cdn.com/gannett-web/apps/teal/dist/teal-ima-a6d09a96.min.js",vCs:"https://www.gannett-cdn.com/gannett-web/apps/teal/dist/vendor/comscore/streamsense-5.1.1.160316.min.js",vICs:"https://www.gannett-cdn.com/gannett-web/apps/teal/dist/teal-comscore-f1701de9.min.js",vHbMSDK:"https://www.gannett-cdn.com/gannett-web/apps/teal/dist/vendor/adobe/MediaSDK.2.2.0.min.js",vHbVApi:"https://www.gannett-cdn.com/gannett-web/apps/teal/dist/vendor/adobe/VisitorAPI-3.4.0.min.js",vHbAppM:"https://www.gannett-cdn.com/gannett-web/apps/teal/dist/vendor/adobe/AppMeasurement-2.11.0.min.js",vIHb:"https://www.gannett-cdn.com/gannett-web/apps/teal/dist/teal-heartbeat-6c3c72e8.min.js",vHls:"https://www.gannett-cdn.com/gannett-web/apps/teal/dist/vendor/hls/hls.light.0.12.4.min.js",vIHls:"https://www.gannett-cdn.com/gannett-web/apps/teal/dist/teal-hls-0887d8c7.min.js",
# tEncore:"https://www.gannett-cdn.com/gannett-web/apps/teal/dist/encore-c29e248c.min.js",tShare:"https://www.gannett-cdn.com/gannett-web/apps/teal/dist/share-454f9438.min.js",tCntrls:"https://www.gannett-cdn.com/gannett-web/apps/teal/dist/controls-4edfda22.min.js",tP:"https://www.gannett-cdn.com/gannett-web/apps/teal/dist/tealplayer-3928e7f8.min.js"};
#
# ;g$.ut("gnt bodyendDone");
#   </script>
#   <script async="" onerror="document.querySelectorAll('.gnt__hbd').forEach(e=&gt;e.classList.remove('gnt__hbd'))" src="/tangstatic/js/main-q1a2z39e4056db.min.js">
#   </script>
#   <script data-tmpl-key="navgdp" type="gnt/tmpl">
#    <div class="gnt_n_dd_oy gnt_n_dd__sz" data-g-r=nav_oy></div><div class="gnt_n_dd gnt_n_dd__sz" data-g-r="nav_dd nav_te nav_ff" tabindex=0></div>|styles|[data-g-s=nav_ao] .gnt_n_dd_bt_svg{transform:rotate(180deg);background:currentColor;fill:#303030}.gnt_n_dd_oy{display:none;left:0;right:0;height:calc(var(--gnt-vh,100vh) - 160px - var(--gnt-sh,0px))}.gnt_n_dd{overscroll-behavior-y:contain;overflow:auto;overflow-x:hidden;box-sizing:border-box;display:none;width:385px;height:calc(var(--gnt-vh,100vh) - 160px - var(--gnt-sh,0px));margin:0 0 0 -20px;padding:7px 20px 0 32px;border-top:5px solid #0098fe;background:#303030;color:#fff}.gnt__hnb .gnt_n_dd__sz{height:calc(var(--gnt-vh,100vh) - 80px - var(--gnt-sh,0px))}[data-g-s=nav_ao] .gnt_n_dd__sz{display:block;position:absolute}
#   </script>
#   <script data-tmpl-key="navse" type="gnt/tmpl">
#    <form class=gnt_n_se_fm data-g-r=nav_dd action=/search/ role=search><input class=gnt_n_se_fm_qr data-g-r=nav_pf name=q placeholder="What can we help you find?" mozactionhint=search enterkeyhint=search aria-label="Search query"/><button class=gnt_n_se_fm_sm data-t-l=${se}|H1Nav|search| aria-label=Submit><svg class=gnt_n_se_fm_sm_svg viewBox="0 0 18 18"><path d="M12.28 9.76H2V7.74h10.28l-2.23-2.31L11.43 4 16 8.75l-4.57 4.75-1.38-1.43 2.23-2.31z"/></svg></button></form>|styles|.gnt_n_se_fm{display:none;align-items:center;justify-content:center;position:absolute;left:0;right:0;height:180px;padding:0 0 15px;border-top:5px solid #0098fe;background:#303030}[data-g-s~=nav_ao] .gnt_n_se_fm{display:flex}.gnt_n_se_fm_qr{width:492px;height:46px;padding:0 50px 0 0;border-style:solid;border-width:0 0 2px;border-color:#fff;border-radius:0;outline:0;background:0 0;color:#fff;font:700 28px 'Unify Sans','Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif}.gnt_n_se_fm_qr::placeholder{opacity:1;color:#fff}.gnt_n_se_fm_qr:-webkit-autofill{box-shadow:inset 0 46px #303030;-webkit-text-fill-color:#fff}.gnt_n_se_fm_sm{width:60px;height:50px;border:0;margin:0 -15px 0 -45px;padding:0;outline-offset:-8px;fill:#fff;background:0 0;cursor:pointer}.gnt_n_se_fm_sm:hover{fill:#e0e0e0}.gnt_n_se_fm_sm_svg{width:42px;height:42px;margin-top:3px;stroke:#303030;stroke-width:.5px}
#   </script>
#   <script data-tmpl-key="navus" type="gnt/tmpl">
#    <div class=gnt_n_us_dd data-g-r=nav_dd><div class=gnt_n_us_dd_u><a class=gnt_n_us_dd_a href=https://account.usatoday.com/ data-t-l="|H1Nav|account|manage account">Manage Account</a> <a class=gnt_n_us_dd_a data-u-sr="anon sub" href=https://user.usatoday.com/user/enewspaper data-t-l="|H1Nav|account|access enewspaper">Access eNewspaper</a> <a class=gnt_n_us_dd_a href=https://profile.usatoday.com/newsletters/manage/ data-t-l=|H1Nav|account|newsletters>Newsletters</a> <a class=gnt_n_us_dd_a data-u-sr="anon sub" href=https://account.usatoday.com/pay data-t-l="|H1Nav|account|pay bill">Pay Bill</a> <a class=gnt_n_us_dd_a data-u-sr="anon sub" href=https://account.usatoday.com/delivery-issue data-t-l="|H1Nav|account|report delivery issues">Report Delivery Issues</a> <a class=gnt_n_us_dd_a data-u-sr="anon sub" href=https://account.usatoday.com/delivery-temporary-stop data-t-l="|H1Nav|account|pause delivery">Pause Delivery</a> <a class=gnt_n_us_dd_a href=https://help.usatoday.com data-t-l="|H1Nav|account|help center">Help Center</a> <a class="gnt_n_us_dd_a gnt_n_us_dd_a__li" data-u-sr="reg sub" href="https://user.usatoday.com/USAT-GUP/user/logout/?return-url=https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Feconomy%2F2018%2F05%2F10%2Fcost-of-living-value-of-dollar-in-every-state%2F34567549%2F" data-t-l="|H1Nav|account|sign out">Sign Out</a></div><div class=gnt_n_us_dd_ac data-u-sr="anon reg"><div class=gnt_n_us_dd_lbl data-u-sr=anon>Have an existing account?</div><a class="gnt_n_us_dd_ba gnt_n_us_dd_ba__hl" data-u-sr=anon rel=nofollow href="https://login.usatoday.com/USAT-GUP/authenticate?success-url=https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Feconomy%2F2018%2F05%2F10%2Fcost-of-living-value-of-dollar-in-every-state%2F34567549%2F&cancel-url=https%3A%2F%2Fwww.usatoday.com%2Fstory%2Fmoney%2Feconomy%2F2018%2F05%2F10%2Fcost-of-living-value-of-dollar-in-every-state%2F34567549%2F" data-t-l="|H1Nav|account|sign in">Sign In</a><div class=gnt_n_us_dd_lbl>Already have a subscription?</div><a class=gnt_n_us_dd_ba rel=nofollow href=https://cm.usatoday.com/account-activation/ data-t-l="|H1Nav|account|activate account">Activate account</a><div class=gnt_n_us_dd_lbl data-u-sr=anon>Don't have an account?</div><a class="gnt_n_us_dd_ba gnt_n_us_dd_a__li" data-u-sr=anon rel=nofollow href="https://login.usatoday.com/authenticate/?requested-state=create-account&amp;reg_source=CPNAVBAR&amp;reg_medium=ONSITE&amp;reg_campaign=signin&amp;reg_delivery=ux" data-t-l="|H1Nav|account|create account">Create account</a></div></div>|styles|.gnt_n_us_a_w{position:relative}.gnt_n_us_dd{display:none;position:absolute;top:28px;right:25px;padding:14px 0 14px 15px;border-top:5px solid #0098fe;background:#303030}[data-g-s~=nav_ao] .gnt_n_us_dd{display:flex}.gnt_n_us_dd_u{display:flex;flex-direction:column;min-width:165px;padding-right:15px}.gnt_n_us_dd_a{margin:3px auto 4px 3px;padding:0 2px;color:#fff;font:700 14px/18px 'Unify Sans','Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif;text-decoration:none;white-space:nowrap}.gnt_n_us_dd_a:hover{color:#e0e0e0}.gnt_n_us_dd_ac{padding:0 15px 0 19px;border-left:1px solid #626262}.gnt_n_us_dd_lbl{margin:5px 0 0;color:#fff;font:700 12px/16px 'Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif}.gnt_n_us_dd_ba{display:block;width:192px;margin:3px 0 19px;padding:9px 1px 8px;border:3px solid #1665cf;outline-offset:-1px;color:#fff;font:700 14px/17px 'Unify Sans','Helvetica Neue','Arial Nova',Helvetica,Arial,sans-serif;text-decoration:none;text-align:center}.gnt_n_us_dd_ba__hl{padding:12px 4px 11px!important;border:0!important;background:var(--gnt-bc,#1665cf)}.gnt_n_us_dd_ba:hover{padding:8px 0 7px;border-width:4px;--gnt-bc:#0A32A0}.gnt_n_us_dd_a__li{margin-bottom:6px}
#   </script>
#   <link as="fetch" crossorigin="use-credentials" href="/global-q1a2z3C4M2nNlQYzWhCC0oMSEFjQbW1KA.min.json" rel="preload" type="application/json"/>
#   <link href="//images.taboola.com" rel="dns-prefetch"/>
#   <link href="https://images.taboola.com" rel="preconnect"/>
#   <script type="application/ld+json">
#    [{"@context":"http://schema.org","@type":"NewsArticle","headline":"Cost of living: The purchasing power of a dollar in every state","description":"While a dollar bill looks and feels the same all over the United States, its value is often very different depending on where it is spent.","url":"https://www.usatoday.com/story/money/economy/2018/05/10/cost-of-living-value-of-dollar-in-every-state/34567549/","mainEntityOfPage":{"@type":"WebPage","@id":"https://247wallst.com/special-report/2018/05/04/value-of-a-dollar-in-every-state/"},"isBasedOn":"https://247wallst.com/special-report/2018/05/04/value-of-a-dollar-in-every-state/","thumbnailUrl":"https://www.gannett-cdn.com/-mm-/de47786e52724b886dffba742cc90d90a58f8b4b/c=0-0-906-906/local/-/media/2018/05/04/USATODAY/usatsports/247WallSt.com-247WS-460988-0873aa10.jpg?width=150&height=150&fit=crop&format=pjpg&auto=webp","image":{"@type":"ImageObject","url":"https://www.gannett-cdn.com/-mm-/ee0f301149bc1263bd57862fdbee99a349f9c25d/c=0-198-907-708/local/-/media/2018/05/04/USATODAY/usatsports/247WallSt.com-247WS-460988-0873aa10.jpg?width=907&height=453&fit=crop&format=pjpg&auto=webp","height":800,"width":1600},"datePublished":"2018-05-10T12:00:03.107Z","dateCreated":"2018-05-10T12:00:03.107Z","dateModified":"2018-05-10T12:00:03.107Z","articleSection":"money","publisher":{"@type":"Organization","name":"24/7 Wall Street","logo":{"@type":"ImageObject","url":"https://www.gannett-cdn.com/sites/usatoday/images/site-nav-logo@2x.png","height":80,"width":297}},"author":["Michael B. Sauter"],"keywords":["ssts:money:economy","type:story","tag:Cost of living","tag:Economy"],"metadata":"{\"id\":\"34567549\",\"siteCode\":\"USAT\",\"contentSourceCode\":\"WLST\",\"ssts\":\"money:economy\",\"type\":\"story\"}"},{"@context":"http://schema.org","@type":"ImageObject","url":"https://www.gannett-cdn.com/-mm-/ee0f301149bc1263bd57862fdbee99a349f9c25d/c=0-198-907-708/local/-/media/2018/05/04/USATODAY/usatsports/247WallSt.com-247WS-460988-0873aa10.jpg","caption":"While a dollar bill looks and feels the same all over the United States, its value is often very different depending on where it is spent. The prices of housing, food, and services vary considerably across the country. To shed light on these differences that reflect the relative purchasing power of Americans in every state, [&#8230;]","copyrightHolder":"Petr Kratochvil / Public Domain Pictures"},{"@context":"http://schema.org","@type":"ImageObject","url":"https://www.gannett-cdn.com/-mm-/24754b2f2e29acd0de721e6d1970b9845a25ca54/c=0-0-1356-766/local/-/media/2018/05/04/USATODAY/usatsports/247WallSt.com-247WS-460988-flu-arizona.jpg","caption":"Arizona","copyrightHolder":"tonda / iStock"},{"@context":"http://schema.org","@type":"ImageObject","url":"https://www.gannett-cdn.com/-mm-/b2b05a4ab25f4fca0316459e1c7404c537a89702/c=0-0-1365-768/local/-/media/2018/05/04/USATODAY/usatsports/247WallSt.com-247WS-460988-631c5a03.jpg","caption":"St. Augustine-St. Johns County, Fla.","copyrightHolder":"Thinkstock"},{"@context":"http://schema.org","@type":"ImageObject","url":"https://www.gannett-cdn.com/-mm-/930a1a2e3f34daa7c92bb1739dcac636f0867120/c=0-0-1366-768/local/-/media/2018/05/04/USATODAY/usatsports/indianapolis-indiana.jpg","caption":"Indianapolis,Ind.","copyrightHolder":"Thinkstock"},{"@context":"http://schema.org","@type":"ImageObject","url":"https://www.gannett-cdn.com/-mm-/24754b2f2e29acd0de721e6d1970b9845a25ca54/c=0-0-1356-766/local/-/media/2018/05/04/USATODAY/usatsports/baltimore-inner-harbor-maryland-e1457620984215.jpg","caption":"Baltimore, Md.","copyrightHolder":"Thinkstock"},{"@context":"http://schema.org","@type":"ImageObject","url":"https://www.gannett-cdn.com/-mm-/50060d60b0ecca62ea4db97e1709321dd3b8e97e/c=1-0-1366-768/local/-/media/2018/05/04/USATODAY/usatsports/newark-at-night-new-jersey-e1456427926788.jpg","caption":"Newark, N.J.","copyrightHolder":"Thinkstock"},{"@context":"http://schema.org","@type":"ImageObject","url":"https://www.gannett-cdn.co ...
#   </script>
#  </body>
# </html>

# %%
# This result shows the class which contains all the states and the corresponding info
results = soup.find_all('div', class_="gnt_ar_b")
results
# Out:
# [<div class="gnt_ar_b"><aside aria-label="Video - How much money you need to earn to be considered rich in these cities" class="gnt_em gnt_em__fp gnt_em_vp__tp gnt_em__el"><div aria-live="polite" class="gnt_em_vp_w" data-c-vt="teal" data-g-r="vp_tp" data-t-pl="teal-hero"><button aria-label="Play video" class="gnt_em_vp_a gnt_em_vp__tp_a" data-c-vpattrs='{"muted":true,"xprp":1,"bContent":false,"an":"usatoday","pn":"USA TODAY","vidNum":1,"docking":true}' data-c-vpdata='{"adsEnabled":true,"awsPath":"money","byline":"Buzz60","canonicalURL":"","contentSourceCode":"BZ60","createDate":"2018-02-27T13:17:23.817Z","credit":"Buzz60","duration":86698,"headline":"","hlsURL":"","id":"110885214","image":{"url":"http://www.gannett-cdn.com/-mm-/621b37bf60a76adf00ec82d1926457b31d7ab3b6/c=0-30-580-356&amp;r=1280x720/local/-/media/2018/02/24/USATODAY/usatsports/large-pile-of-hundred-dollar-bills-cash-money-savings-rich_large.jpg","opto":true},"initialPublishDate":"2018-02-27T13:27:17.587Z","keywords":"Simply Money,Cities","mp4URL":"https://media.gannett-cdn.com/29906170001/29906170001_5741306034001_5741306116001.mp4","origin":"Buzz60","pageURL":{"long":"https://www.usatoday.com/videos/money/2018/02/27/how-much-money-you-need-earn-considered-rich-these-cities/110885214/"},"promoBrief":"The Business Insider got a little more specific and analyzed data to figure out, how much exactly do you need to make in order to be considered rich in these top US cities. Susana Victoria Perez (@susana_vp) has more.","publishDate":"2018-02-27T13:27:17.587Z","series":"","ssts":{"section":"money","subsection":"","topic":"","subtopic":""},"tags":[{"id":"1660aeab-4a3d-4952-9733-0381dab75157","name":"Cities"},{"id":"34b6a1e2-fa92-4d95-a1a0-89d20bc5ca74","name":"Simply Money"}],"title":"How much money you need to earn to be considered rich in these cities","url":"/videos/money/2018/02/27/how-much-money-you-need-earn-considered-rich-these-cities/110885214/"}' data-g-r="vp_ap vp_tg"><img alt="" class="gnt_em_vp_img" data-g-r="vp_po" decoding="async" elementtiming="ar-lead-image" src="http://www.gannett-cdn.com/-mm-/621b37bf60a76adf00ec82d1926457b31d7ab3b6/c=0-30-580-356&amp;r=1280x720/local/-/media/2018/02/24/USATODAY/usatsports/large-pile-of-hundred-dollar-bills-cash-money-savings-rich_large.jpg?width=660&amp;height=371&amp;fit=crop&amp;format=pjpg&amp;auto=webp"/><svg class="gnt_em_vp_svg"><use xlink:href="#gnt_svg_video_play"></use></svg></button><div class="gnt_em_vp_c"><button aria-label="Close docked video player" class="gnt_em_vp_db" data-t-l="${tc}|tealplayer|playerClose"><svg viewbox="0 0 16 16"><path d="M9 7.625L13.125 3.5 14.5 4.875 10.375 9l4.125 4.125-1.375 1.375L9 10.375 4.875 14.5 3.5 13.125 7.625 9 3.5 4.875 4.875 3.5 9 7.625z"></path></svg></button></div></div><div class="gnt_em_vt" data-c-et="How much money you need to earn to be considered rich in these cities"></div><div aria-label="The Business Insider got a little more specific and analyzed data to figure out, how much exactly do you need to make in order to be considered rich in these top US cities. Susana Victoria Perez (@susana_vp) has more." class="gnt_em_vb gnt_em_vb__te" data-c-credit="Buzz60"></div></aside><p class="gnt_ar_b_p">While a dollar bill looks and feels the same all over the United States, its value is often very different depending on where it is spent.</p><p class="gnt_ar_b_p">The prices of housing, food, and services vary considerably across the country. To shed light on these differences that reflect the relative purchasing power of Americans in every state, 24/7 Wall St. calculated the value of a dollar in each using data from the Bureau of Economic Analysis.</p><p class="gnt_ar_b_p">The value of a dollar, of course, is higher in places where goods and services are less expensive. For the most part, the areas with a low cost of living are in the South. By contrast, the most expensive states -- where the dollar is worth the least -- are home to some of the nation’s largest urban  ...

# %%
for result in results:
    
    # Retrieve the thread title
    title = result.find_all('p', class_="gnt_ar_b_p")
    value = result.find_all('ul', class_="gnt_ar_b_ul")
    
#     print(title)
    print(value)

# %%
state_names = []
value = []

for x in range(len(results)):
    state_names.append(result.find_all('p', class_="gnt_ar_b_p"))
    value.append(result.find_all('ul', class_="gnt_ar_b_ul"))

value_of_dolar = pd.DataFrame({'Name': state_names, "Value": value})
value_of_dolar
# Out:
#                                                 Name  \
# 0  [[While a dollar bill looks and feels the same...
#
#                                                Value
# 0  [[[<strong>Value of a dollar:</strong>,  $1.15...
